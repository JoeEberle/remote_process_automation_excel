# %% [markdown]
# ![remote_process_automation%20excel%20II.png](attachment:remote_process_automation%20excel%20II.png)

# %% [markdown]
# # Remote Process Automation Excel
# ##### Created Joe Eberle - 11/23/2022

# %% [markdown]
# ## Required Step 0 - Import all Libraries needed

# %%
import glob 
import rpa_excel as re
from openpyxl.styles import numbers

# %% [markdown]
# ## Optional Step 0 - First time - One time - pip install Libraries

# %%
# ! pip install openpyxl
# ! pip install configparser
# ! pip install datetime
# requires quick_logger.py
# requires rpa_excel.py

# %% [markdown]
# ## Optional Step 0 - Intitiate Configuration Settings and name the overall solution

# %%
# Install any libraries you dont already have installed 
import configparser   
from datetime import date, datetime

# establish the configuration settings parser
config = configparser.ConfigParser()  
cfg = config.read('config.ini')   

# Establish some parameters 
solution_name = 'remote_process_automation_excel'

# %% [markdown]
# ## Optional Step 0 - Intitiate the Logger

# %%
# Establish the Python Logger  
import logging # built in python library that does not need to be installed 
import quick_logger as ql

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_Start(solution_name, start_time)

# %% [markdown]
# ## Step 1 -Format Entire Directory of Excel Files

# %%
testing = False
if testing:
    formatted_excel_Files = re.format_excel_directory('J:\IT GLIN Data Services Shared\TempData')
    print(f'Formatted #{formatted_excel_Files} excel files')

# %%
testing = True
if testing:
    formatted_excel_Files = re.format_excel_directory('C:\working_directory\excel')
    print(f'/n/nFormatted #{formatted_excel_Files} excel files')
# Out:
# Found 28 excel files in directory:C:\working_directory\excel
# File name to be loaded:C:\working_directory\excel\adventure 2023.xlsx
#
#
# Formatting file:C:\working_directory\excel\adventure 2023.xlsx with maximum Columns:7 template:standard
# after add logo
# format_column_header max_row:54 max_col:6
# format_column_header value:None
# format_column_header value:hike niagara falls  or gorge
# format_column_header value:1
# format_column_header value:=F1
# format_column_header value:=D1
# format_column_header value:=TODAY() +3
# formatting number column type with header:NONE
# formatting number column type with header:HIKE NIAGARA FALLS  OR GORGE
# formatting number column type with header:1
# formatting number column type with header:=F1
# formatting number column type with header:=D1
# formatting number column type with header:=TODAY() +3
# Formatting file:C:\working_directory\excel\adventure 2023.xlsx with maximum Coluns:7 template:standard
#
# Read in raw file:C:\working_directory\excel\adventure 2023.xlsx
# Worksheet Sheet1
# Formatted:C:\working_directory\excel\adventure 2023_ft.xlsx
# File name to be loaded:C:\working_directory\excel\AIHS_patient.xlsx
#
#
# Formatting file:C:\working_directory\excel\AIHS_patient.xlsx with maximum Columns:493 template:standard
# after add logo
# format_column_header max_row:1002 max_col:492
# format_column_header value:None
# format_column_header value:Index
# format_column_header value:Year
# format_column_header value:Patient Ordinal
# format_column_header value:Birth Date
# format_column_header value:Age
# format_column_header value:Decade
# format_column_header value:Gender
# format_column_header value:Race
# format_column_header value:Race Category
# format_column_header value:Diabetes
# format_column_header value:Diabetic Metabolic Syndrome
# format_column_header value:ADA Risk
# format_column_header value:Family Member with Diabetes
# format_column_header value:Physical Activity Minutes
# format_column_header value:Activity Level
# format_column_header value:Activity Quartile
# format_column_header value:High Blood Pressure Response
# format_column_header value:High Blood Pressure
# format_column_header value:Height in Inches
# format_column_header value:Height in Centimeters
# format_column_header value:Patients weight in lbs
# format_column_header value:Weight in KG
# format_column_header value:BMI
# format_column_header value:BMII
# format_column_header value:BMI Class
# format_column_header value:ADA Family Risk
# format_column_header value:ADA Age Risk
# format_column_header value:ADA Gender Risk
# format_column_header value:ADA BMI Risk
# format_column_header value:ADA Hypertension Risk
# format_column_header value:Total Calculated ADA pre-Diabetes Risk
# format_column_header value:AIHS Age Risk
# format_column_header value:AIHS BMI Risk
# format_column_header value:Total Calculated AIHS Risk Stratifcation
# format_column_header value:Simulated BMI Class
# format_column_header value:Simulated Activity Class
# format_column_header value:Patient Cohort
# format_column_header value:Number  of  Claims
# format_column_header value:Emergency  Department  Visit  count
# format_column_header value:Inpatient  Admission  count
# format_column_header value:Institutional  Claim  Count
# format_column_header value:Professional  Claim  Count
# format_column_header value:Pharmacy  Claim  Count
# format_column_header value:Dental  Claim  Count
# format_column_header value: Total  Paid  Amount
# format_column_header value: Per  Patient  Per  Year  Amount
# format_column_header value: Per  Patient  Per  Month  Amount
# format_column_header value:Per  Patient  Per  Year  Utilization
# format_column_header value:Per  Patient  Per  Month  Utilization
# format_column_header value:Alternative  ED  Visit  Claim  Count
# format_column_header value:Alternative  IP  Admission  Claim  Count
# format_column_header value:Number  of  Endocrine  Nutritional  Metabolic  Immunity  Disorders  Claims
# format_column_header value:Number  of  Congenital  Anomalies  Claims
# format_column_header value:Number  of  Genitourinary  System  Claims
# format_column_header value:Number  of  Symptoms  Signs  Ill  Defined  Conditions  Claims
# format_column_header value:Number  of  Circulatory  System  Claims
# format_column_header value:Number  of  Respiratory  System  Claims
# format_column_header value:Number  of  Diseases  of  the  Blood  Claims
# format_column_header value:Number  of  Infectious  and  parasitic  diseases  Claims
# format_column_header value:Number  of  Mental  Illness  Claims
# format_column_header value:Number  of  Neoplasms  Claims
# format_column_header value:Number  of  Diseases  of  the  Nervous  System  Claims
# format_column_header value:Number  of  Diseases  of  the  Digestive  System  Claims
# format_column_header value:Number  of  Diseases  of  the  Musculoskeletal  System  Claims
# format_column_header value:Number  of  Injury  and  Poisoning  Claims
# format_column_header value:Number  of  Residual  Codes  Unclassified  Claims
# format_column_header value:Number  of  Complications  of  Pregnancy  Childbirth  Claims
# format_column_header value:Number  of  Perinatal  Period  Claims
# format_column_header value:Number  of  Diseases  of  the  Skin  Claims
# format_column_header value:Patient  Ordinal.1
# format_column_header value:Weight Current
# format_column_header value:Weight Period 1
# format_column_header value:Weight Period 2
# format_column_header value:Weight Period 3
# format_column_header value:Weight Period 4
# format_column_header value:Weight Period 5
# format_column_header value:HBA1c Period 5
# format_column_header value:BP Diastolic Current
# format_column_header value:BP Diastolic  Period 1
# format_column_header value:BP Diastolic  Period 2
# format_column_header value:BP Diastolic  Period 3
# format_column_header value:BP Diastolic  Period 4
# format_column_header value:BP Diastolic  Period 5
# format_column_header value:BP Systolic Current
# format_column_header value:BP Systolic Period 1
# format_column_header value:BP Systolic Period 2
# format_column_header value:BP Systolic Period 3
# format_column_header value:BP Systolic Period 4
# format_column_header value:BP Systolic Period 5
# format_column_header value:LDL Current
# format_column_header value:LDL Period 1
# format_column_header value:LDL Period 2
# format_column_header value:LDL Period 3
# format_column_header value:LDL Period 4
# format_column_header value:LDL Period 5
# format_column_header value:HDL Current
# format_column_header value:HDL Period 1
# format_column_header value:HDL Period 2
# format_column_header value:HDL Period 3
# format_column_header value:HDL Period 4
# format_column_header value:HDL Period 5
# format_column_header value:BRFSS Index
# format_column_header value:_STATE
# format_column_header value:FMONTH
# format_column_header value:IDATE
# format_column_header value:IMONTH
# format_column_header value:IDAY
# format_column_header value:IYEAR
# format_column_header value:DISPCODE
# format_column_header value:SEQNO
# format_column_header value:_PSU
# format_column_header value:CTELENUM
# format_column_header value:PVTRESD1
# format_column_header value:COLGHOUS
# format_column_header value:STATERES
# format_column_header value:CELLFON3
# format_column_header value:LADULT
# format_column_header value:NUMADULT
# format_column_header value:NUMMEN
# format_column_header value:NUMWOMEN
# format_column_header value:CTELNUM1
# format_column_header value:CELLFON2
# format_column_header value:CADULT
# format_column_header value:PVTRESD2
# format_column_header value:CCLGHOUS
# format_column_header value:CSTATE
# format_column_header value:LANDLINE
# format_column_header value:HHADULT
# format_column_header value:GENHLTH
# format_column_header value:PHYSHLTH
# format_column_header value:MENTHLTH
# format_column_header value:POORHLTH
# format_column_header value:HLTHPLN1
# format_column_header value:PERSDOC2
# format_column_header value:MEDCOST
# format_column_header value:MEDCOST   Was there a time during the past 12 months when you needed to see a doctor, but could not because of the cost? ?  1=Yes 2=No 7=DK/Not sure 9=Refused
# format_column_header value:CHECKUP1
# format_column_header value:CHECKUP1  About how long has it been since you last visited a doctor for a routine checkup?  ?  1=Yes 2=No 7=DK/Not sure 9=Refused
# format_column_header value:BPHIGH4
# format_column_header value:BPHIGH4  Have you ever been told by a doctor, nurse, or other health professional that you have high blood pressure??  1=Yes 2=No 7=DK/Not sure 9=Refused
# format_column_header value:BPMEDS
# format_column_header value:BPMEDS   Are you currently taking medicine for your high blood pressure? ?  1=Yes 2=No 7=DK/Not sure 9=Refused
# format_column_header value:BLOODCHO
# format_column_header value:BLOODCHO   Blood cholesterol is a fatty substance found in the blood.  Have you ever had your blood cholesterol checked? ?          1=Yes 2=No 7=DK/Not sure 9=Refused
# format_column_header value:CHOLCHK
# format_column_header value:CHOLCHK   when was cholesterol checked?
# format_column_header value:TOLDHI2
# format_column_header value:TOLDHI2   Ever told  blood cholesterol is high? ?  1=Yes 2=No 7=DK/Not sure 9=Refused
# format_column_header value:CVDINFR4
# format_column_header value:CVDINFR4   Ever told you have heart attack, also called a myocardial infarction ?  1=Yes 2=No 7=DK/Not sure 9=Refused
# format_column_header value:CVDCRHD4
# format_column_header value:CVDCRHD4  Ever told you have angina or coronary heart disease ?  1=Yes 2=No 7=DK/Not sure 9=Refused
# format_column_header value:CVDSTRK3
# format_column_header value:CVDSTRK3   Ever told you have Stroke ?    1=Yes 2=No 7=DK/Not sure 9=Refused
# format_column_header value:ASTHMA3
# format_column_header value:ASTHMA3   Ever told you have Asthma ?  1=Yes 2=No 7=DK/Not sure 9=Refused
# format_column_header value:ASTHNOW
# format_column_header value:ASTHNOW Do you still have asthma?  1=Yes 2=No 7=DK/Not sure 9=Refused
# format_column_header value:CHCSCNCR
# format_column_header value:CHCSCNCR (Ever told) you have Skin Cancer?  1=Yes 2=No 7=DK/Not sure 9=Refused
# format_column_header value:CHCOCNCR
# format_column_header value:CHCOCNCR (Ever told) you have other types of Cancer?  1=Yes 2=No 7=DK/Not sure 9=Refused
# format_column_header value:CHCCOPD1
# format_column_header value:CHCCOPD1 (Ever told) you have Chronic Obstructive Pulmonary Disease or COPD, emphysema or chronic bronchitis?  1=Yes 2=No 7=DK/Not sure 9=Refused
# format_column_header value:HAVARTH3
# format_column_header value:ADDEPEV2 -  Ever been Told you have Arthritis ?    1=Yes 2=No 7=DK/Not sure 9=Refused
# format_column_header value:ADDEPEV2
# format_column_header value:ADDEPEV2 -  Ever been Told you have Deppresion or Depressive Disorder?    1=Yes 2=No 7=DK/Not sure 9=Refused
# format_column_header value:CHCKIDNY
# format_column_header value:CHCKIDNY - Ever been Told you have Kidney Disease?  1=Yes 2=No 7=DK / Not sure 9=Refused
# format_column_header value:DIABETE3
# format_column_header value:DIABETE3 Ever been Told you have Diabetes? 1=Yes 2=Yes, but female told only during pregnancy 3=No 4=No, pre-diabetes or borderline diabetes 7=DK/NS 9=Refused
# format_column_header value:DIABAGE2
# format_column_header value:DIABAGE2 Age told of Diabetes 1-97=Age in years  [97 = 97 and older] 98=Don’t know/Not sure 99=Refused
# format_column_header value:SEX
# format_column_header value:SEX 1=Male 2=Female 7=Don’t know/Not Sure 9=Refused
# format_column_header value:MARITAL
# format_column_header value:Marital  1=Married  2=Divorced  3=Widowed  4=Separated  5=Never married  6=A member of an unmarried couple  9=Refused
# format_column_header value:EDUCA
# format_column_header value:EDUCA 1=Never attended school or only attended kindergarten  2=Grades 1 through 8 (Elementary)  3=Grades 9 through 11 (Some high school)  4=Grade 12 or GED (High school graduate)  5=College 1 year to 3 years (Some college or technical school)  6=College 4 years
# format_column_header value:RENTHOM1
# format_column_header value:Do you own or rent your home? 1=Own  2=Rent  3=Other arrangement
# format_column_header value:NUMHHOL2
# format_column_header value:1=Yes 2=No 7=DK / Not sure 9=Refused
# format_column_header value:NUMPHON2
# format_column_header value:1=Yes 2=No 7=DK / Not sure 9=Refused.1
# format_column_header value:CPDEMO1
# format_column_header value:1=Yes 2=No 7=DK / Not sure 9=Refused.2
# format_column_header value:VETERAN3
# format_column_header value:1=Yes 2=No 7=DK / Not sure 9=Refused.3
# format_column_header value:EMPLOY1
# format_column_header value:1=Yes 2=No 7=DK / Not sure 9=Refused.4
# format_column_header value:CHILDREN
# format_column_header value:1=Yes 2=No 7=DK / Not sure 9=Refused.5
# format_column_header value:INCOME2
# format_column_header value:04=Less than $25,000   ($20,000 to less than $25,000)   03=Less than $20,000   ($15,000 to less than $20,000)   02=Less than $15,000   ($10,000 to less than $15,000)   01=Less than $10,000   05=Less than $35,000   ($25,000 to less than $35,000)   06=Less
# format_column_header value:INTERNET
# format_column_header value:1=Yes 2=No 7=DK / Not sure 9=Refused.6
# format_column_header value:WEIGHT2
# format_column_header value:HEIGHT3
# format_column_header value:PREGNANT
# format_column_header value:QLACTLM2
# format_column_header value:USEEQUIP
# format_column_header value:BLIND
# format_column_header value:DECIDE
# format_column_header value:DIFFWALK
# format_column_header value:DIFFDRES
# format_column_header value:DIFFALON
# format_column_header value:SMOKE100
# format_column_header value:SMOKDAY2
# format_column_header value:STOPSMK2
# format_column_header value:LASTSMK2
# format_column_header value:USENOW3
# format_column_header value:ALCDAY5
# format_column_header value:AVEDRNK2
# format_column_header value:DRNK3GE5
# format_column_header value:MAXDRNKS
# format_column_header value:FRUITJU1
# format_column_header value:FRUIT1
# format_column_header value:FVBEANS
# format_column_header value:FVGREEN
# format_column_header value:FVORANG
# format_column_header value:VEGETAB1
# format_column_header value:EXERANY2
# format_column_header value:EXRACT11
# format_column_header value:EXEROFT1
# format_column_header value:EXERHMM1
# format_column_header value:EXRACT21
# format_column_header value:EXEROFT2
# format_column_header value:EXERHMM2
# format_column_header value:STRENGTH
# format_column_header value:LMTJOIN3
# format_column_header value:ARTHDIS2
# format_column_header value:ARTHSOCL
# format_column_header value:JOINPAIN
# format_column_header value:SEATBELT
# format_column_header value:FLUSHOT6
# format_column_header value:FLSHTMY2
# format_column_header value:IMFVPLAC
# format_column_header value:PNEUVAC3
# format_column_header value:HIVTST6
# format_column_header value:HIVTSTD3
# format_column_header value:WHRTST10
# format_column_header value:PDIABTST
# format_column_header value:PREDIAB1
# format_column_header value:INSULIN
# format_column_header value:BLDSUGAR
# format_column_header value:FEETCHK2
# format_column_header value:DOCTDIAB
# format_column_header value:CHKHEMO3
# format_column_header value:FEETCHK
# format_column_header value:EYEEXAM
# format_column_header value:DIABEYE
# format_column_header value:DIABEDU
# format_column_header value:PAINACT2
# format_column_header value:QLMENTL2
# format_column_header value:QLSTRES2
# format_column_header value:QLHLTH2
# format_column_header value:CAREGIV1
# format_column_header value:CRGVREL1
# format_column_header value:CRGVLNG1
# format_column_header value:CRGVHRS1
# format_column_header value:CRGVPRB1
# format_column_header value:CRGVPERS
# format_column_header value:CRGVHOUS
# format_column_header value:CRGVMST2
# format_column_header value:CRGVEXPT
# format_column_header value:VIDFCLT2
# format_column_header value:VIREDIF3
# format_column_header value:VIPRFVS2
# format_column_header value:VINOCRE2
# format_column_header value:VIEYEXM2
# format_column_header value:VIINSUR2
# format_column_header value:VICTRCT4
# format_column_header value:VIGLUMA2
# format_column_header value:VIMACDG2
# format_column_header value:CIMEMLOS
# format_column_header value:CDHOUSE
# format_column_header value:CDASSIST
# format_column_header value:CDHELP
# format_column_header value:CDSOCIAL
# format_column_header value:CDDISCUS
# format_column_header value:WTCHSALT
# format_column_header value:LONGWTCH
# format_column_header value:DRADVISE
# format_column_header value:ASTHMAGE
# format_column_header value:ASATTACK
# format_column_header value:ASERVIST
# format_column_header value:ASDRVIST
# format_column_header value:ASRCHKUP
# format_column_header value:ASACTLIM
# format_column_header value:ASYMPTOM
# format_column_header value:ASNOSLEP
# format_column_header value:ASTHMED3
# format_column_header value:ASINHALR
# format_column_header value:HAREHAB1
# format_column_header value:STREHAB1
# format_column_header value:CVDASPRN
# format_column_header value:ASPUNSAF
# format_column_header value:RLIVPAIN
# format_column_header value:RDUCHART
# format_column_header value:RDUCSTRK
# format_column_header value:ARTTODAY
# format_column_header value:ARTHWGT
# format_column_header value:ARTHEXER
# format_column_header value:ARTHEDU
# format_column_header value:TETANUS
# format_column_header value:HPVADVC2
# format_column_header value:HPVADSHT
# format_column_header value:SHINGLE2
# format_column_header value:HADMAM
# format_column_header value:HOWLONG
# format_column_header value:HADPAP2
# format_column_header value:LASTPAP2
# format_column_header value:HPVTEST
# format_column_header value:HPLSTTST
# format_column_header value:HADHYST2
# format_column_header value:PROFEXAM
# format_column_header value:LENGEXAM
# format_column_header value:BLDSTOOL
# format_column_header value:LSTBLDS3
# format_column_header value:HADSIGM3
# format_column_header value:HADSGCO1
# format_column_header value:LASTSIG3
# format_column_header value:PCPSAAD2
# format_column_header value:PCPSADI1
# format_column_header value:PCPSARE1
# format_column_header value:PSATEST1
# format_column_header value:PSATIME
# format_column_header value:PCPSARS1
# format_column_header value:PCPSADE1
# format_column_header value:PCDMDECN
# format_column_header value:SCNTMNY1
# format_column_header value:SCNTMEL1
# format_column_header value:SCNTPAID
# format_column_header value:SCNTWRK1
# format_column_header value:SCNTLPAD
# format_column_header value:SCNTLWK1
# format_column_header value:SXORIENT
# format_column_header value:TRNSGNDR
# format_column_header value:RCSGENDR
# format_column_header value:RCSRLTN2
# format_column_header value:CASTHDX2
# format_column_header value:CASTHNO2
# format_column_header value:EMTSUPRT
# format_column_header value:LSATISFY
# format_column_header value:ADPLEASR
# format_column_header value:ADDOWN
# format_column_header value:ADSLEEP
# format_column_header value:ADENERGY
# format_column_header value:ADEAT1
# format_column_header value:ADFAIL
# format_column_header value:ADTHINK
# format_column_header value:ADMOVE
# format_column_header value:MISTMNT
# format_column_header value:ADANXEV
# format_column_header value:QSTVER
# format_column_header value:QSTLANG
# format_column_header value:EXACTOT1
# format_column_header value:EXACTOT2
# format_column_header value:MSCODE
# format_column_header value:_STSTR
# format_column_header value:_STRWT
# format_column_header value:_RAWRAKE
# format_column_header value:_WT2RAKE
# format_column_header value:_CHISPNC
# format_column_header value:_CRACE1
# format_column_header value:_CPRACE
# format_column_header value:_CLLCPWT
# format_column_header value:_DUALUSE
# format_column_header value:_DUALCOR
# format_column_header value:_LLCPWT
# format_column_header value:_RFHLTH
# format_column_header value:_HCVU651
# format_column_header value:_RFHYPE5
# format_column_header value:_CHOLCHK
# format_column_header value:_RFCHOL
# format_column_header value:_MICHD
# format_column_header value:_LTASTH1
# format_column_header value:_CASTHM1
# format_column_header value:_ASTHMS1
# format_column_header value:_DRDXAR1
# format_column_header value:_PRACE1
# format_column_header value:_MRACE1
# format_column_header value:_HISPANC
# format_column_header value:_RACE
# format_column_header value:1=White   2=Black or African American   3=Asian   4=Native Hawaiian or Other Pacific Islander   5=American Indian, Alaska Native   6=Other: [specify]__________   8=No additional choices  7=DK/NS   9=Refused
# format_column_header value:_RACEG21
# format_column_header value:_RACEGR3
# format_column_header value:_RACE_G1
# format_column_header value:_AGEG5YR
# format_column_header value:_AGE65YR
# format_column_header value:_AGE80
# format_column_header value:_AGE_G
# format_column_header value:HTIN4
# format_column_header value:htin4: Computed Height In Inches
# format_column_header value:HTM4
# format_column_header value:WTKG3
# format_column_header value:_BMI5
# format_column_header value:_BMI5 X_bmi5: Computed Body Mass Index
# format_column_header value:_BMI5CAT
# format_column_header value:X_bmi5cat: Computed Body Mass Index Categories
# format_column_header value:_RFBMI5
# format_column_header value:_CHLDCNT
# format_column_header value:_EDUCAG
# format_column_header value:_INCOMG
# format_column_header value:_SMOKER3
# format_column_header value:_RFSMOK3
# format_column_header value:DRNKANY5
# format_column_header value:DROCDY3_
# format_column_header value:_RFBING5
# format_column_header value:_DRNKWEK
# format_column_header value:_RFDRHV5
# format_column_header value:FTJUDA1_
# format_column_header value:FRUTDA1_
# format_column_header value:BEANDAY_
# format_column_header value:GRENDAY_
# format_column_header value:ORNGDAY_
# format_column_header value:VEGEDA1_
# format_column_header value:_MISFRTN
# format_column_header value:_MISVEGN
# format_column_header value:_FRTRESP
# format_column_header value:Unnamed: 422
# format_column_header value:_VEGRESP
# format_column_header value:Unnamed: 424
# format_column_header value:_FRUTSUM
# format_column_header value:Unnamed: 426
# format_column_header value:_VEGESUM
# format_column_header value:X_vegesum: Total Vegetables Consumed Per Day
# format_column_header value:_FRTLT1
# format_column_header value:_VEGLT1
# format_column_header value:_FRT16
# format_column_header value:_VEG23
# format_column_header value:_FRUITEX
# format_column_header value:X_fruitex: Fruit Exclusion From Analyses
# format_column_header value:_VEGETEX
# format_column_header value:X_vegetex: Vegetable Exclusion From Analyses
# format_column_header value:_TOTINDA
# format_column_header value:METVL11_
# format_column_header value:METVL21_
# format_column_header value:MAXVO2_
# format_column_header value:FC60_
# format_column_header value:ACTIN11_
# format_column_header value:ACTIN21_
# format_column_header value:PADUR1_
# format_column_header value:PADUR2_
# format_column_header value:PAFREQ1_
# format_column_header value:PAFREQ2_
# format_column_header value:pafreq2_: Physical Activity Frequency Per Week For Second Activity
# format_column_header value:_MINAC11
# format_column_header value:_MINAC21
# format_column_header value:STRFREQ_
# format_column_header value:PAMISS1_
# format_column_header value:PAMIN11_
# format_column_header value:pamin11_: Minutes Of Physical Activity Per Week For First Activity
# format_column_header value:PAMIN21_
# format_column_header value:pamin21_: Minutes Of Physical Activity Per Week For Second Activity
# format_column_header value:PA1MIN_
# format_column_header value:pa1min_: Minutes Of Total Physical Activity Per Week
# format_column_header value:PAVIG11_
# format_column_header value:PAVIG21_
# format_column_header value:PA1VIGM_
# format_column_header value:_PACAT1
# format_column_header value:_PAINDX1
# format_column_header value:_PA150R2
# format_column_header value:_PA300R2
# format_column_header value:_PA30021
# format_column_header value:_PASTRNG
# format_column_header value:_PAREC1
# format_column_header value:_PASTAE1
# format_column_header value:_LMTACT1
# format_column_header value:_LMTWRK1
# format_column_header value:_LMTSCL1
# format_column_header value:_RFSEAT2
# format_column_header value:_RFSEAT3
# format_column_header value:_FLSHOT6
# format_column_header value:_PNEUMO2
# format_column_header value:_AIDTST3
# format_column_header value:PAM Q1
# format_column_header value:PAM Q2
# format_column_header value:PAM Q3
# format_column_header value:PAM Q4
# format_column_header value:PAM Q5
# format_column_header value:PAM Q6
# format_column_header value:PAM Q7
# format_column_header value:PAM Q8
# format_column_header value:PAM Q9
# format_column_header value:PAM Q10
# format_column_header value:PAM Q11
# format_column_header value:PAM Q12
# format_column_header value:PAM Q13
# formatting number column type with header:NONE
# formatting number column type with header:INDEX
# formatting number column type with header:YEAR
# formatting number column type with header:PATIENT ORDINAL
# formatting number column type with header:BIRTH DATE
# formatting number column type with header:AGE
# formatting number column type with header:DECADE
# formatting number column type with header:GENDER
# formatting number column type with header:RACE
# formatting number column type with header:RACE CATEGORY
# formatting number column type with header:DIABETES
# formatting number column type with header:DIABETIC METABOLIC SYNDROME
# formatting number column type with header:ADA RISK
# formatting number column type with header:FAMILY MEMBER WITH DIABETES
# formatting number column type with header:PHYSICAL ACTIVITY MINUTES
# formatting number column type with header:ACTIVITY LEVEL
# formatting number column type with header:ACTIVITY QUARTILE
# formatting number column type with header:HIGH BLOOD PRESSURE RESPONSE
# formatting number column type with header:HIGH BLOOD PRESSURE
# formatting number column type with header:HEIGHT IN INCHES
# formatting number column type with header:HEIGHT IN CENTIMETERS
# formatting number column type with header:PATIENTS WEIGHT IN LBS
# formatting number column type with header:WEIGHT IN KG
# formatting number column type with header:BMI
# formatting number column type with header:BMII
# formatting number column type with header:BMI CLASS
# formatting number column type with header:ADA FAMILY RISK
# formatting number column type with header:ADA AGE RISK
# formatting number column type with header:ADA GENDER RISK
# formatting number column type with header:ADA BMI RISK
# formatting number column type with header:ADA HYPERTENSION RISK
# formatting number column type with header:TOTAL CALCULATED ADA PRE-DIABETES RISK
# formatting number column type with header:AIHS AGE RISK
# formatting number column type with header:AIHS BMI RISK
# formatting number column type with header:TOTAL CALCULATED AIHS RISK STRATIFCATION
# formatting number column type with header:SIMULATED BMI CLASS
# formatting number column type with header:SIMULATED ACTIVITY CLASS
# formatting number column type with header:PATIENT COHORT
# formatting number column type with header:NUMBER  OF  CLAIMS
# formatting number column type with header:EMERGENCY  DEPARTMENT  VISIT  COUNT
# formatting number column type with header:INPATIENT  ADMISSION  COUNT
# formatting number column type with header:INSTITUTIONAL  CLAIM  COUNT
# formatting number column type with header:PROFESSIONAL  CLAIM  COUNT
# formatting number column type with header:PHARMACY  CLAIM  COUNT
# formatting number column type with header:DENTAL  CLAIM  COUNT
# formatting number column type with header: TOTAL  PAID  AMOUNT
# formatting number column type with header: PER  PATIENT  PER  YEAR  AMOUNT
# formatting number column type with header: PER  PATIENT  PER  MONTH  AMOUNT
# formatting number column type with header:PER  PATIENT  PER  YEAR  UTILIZATION
# formatting number column type with header:PER  PATIENT  PER  MONTH  UTILIZATION
# formatting number column type with header:ALTERNATIVE  ED  VISIT  CLAIM  COUNT
# formatting number column type with header:ALTERNATIVE  IP  ADMISSION  CLAIM  COUNT
# formatting number column type with header:NUMBER  OF  ENDOCRINE  NUTRITIONAL  METABOLIC  IMMUNITY  DISORDERS  CLAIMS
# formatting number column type with header:NUMBER  OF  CONGENITAL  ANOMALIES  CLAIMS
# formatting number column type with header:NUMBER  OF  GENITOURINARY  SYSTEM  CLAIMS
# formatting number column type with header:NUMBER  OF  SYMPTOMS  SIGNS  ILL  DEFINED  CONDITIONS  CLAIMS
# formatting number column type with header:NUMBER  OF  CIRCULATORY  SYSTEM  CLAIMS
# formatting number column type with header:NUMBER  OF  RESPIRATORY  SYSTEM  CLAIMS
# formatting number column type with header:NUMBER  OF  DISEASES  OF  THE  BLOOD  CLAIMS
# formatting number column type with header:NUMBER  OF  INFECTIOUS  AND  PARASITIC  DISEASES  CLAIMS
# formatting number column type with header:NUMBER  OF  MENTAL  ILLNESS  CLAIMS
# formatting number column type with header:NUMBER  OF  NEOPLASMS  CLAIMS
# formatting number column type with header:NUMBER  OF  DISEASES  OF  THE  NERVOUS  SYSTEM  CLAIMS
# formatting number column type with header:NUMBER  OF  DISEASES  OF  THE  DIGESTIVE  SYSTEM  CLAIMS
# formatting number column type with header:NUMBER  OF  DISEASES  OF  THE  MUSCULOSKELETAL  SYSTEM  CLAIMS
# formatting number column type with header:NUMBER  OF  INJURY  AND  POISONING  CLAIMS
# formatting number column type with header:NUMBER  OF  RESIDUAL  CODES  UNCLASSIFIED  CLAIMS
# formatting number column type with header:NUMBER  OF  COMPLICATIONS  OF  PREGNANCY  CHILDBIRTH  CLAIMS
# formatting number column type with header:NUMBER  OF  PERINATAL  PERIOD  CLAIMS
# formatting number column type with header:NUMBER  OF  DISEASES  OF  THE  SKIN  CLAIMS
# formatting number column type with header:PATIENT  ORDINAL.1
# formatting number column type with header:WEIGHT CURRENT
# formatting number column type with header:WEIGHT PERIOD 1
# formatting number column type with header:WEIGHT PERIOD 2
# formatting number column type with header:WEIGHT PERIOD 3
# formatting number column type with header:WEIGHT PERIOD 4
# formatting number column type with header:WEIGHT PERIOD 5
# formatting number column type with header:HBA1C PERIOD 5
# formatting number column type with header:BP DIASTOLIC CURRENT
# formatting number column type with header:BP DIASTOLIC  PERIOD 1
# formatting number column type with header:BP DIASTOLIC  PERIOD 2
# formatting number column type with header:BP DIASTOLIC  PERIOD 3
# formatting number column type with header:BP DIASTOLIC  PERIOD 4
# formatting number column type with header:BP DIASTOLIC  PERIOD 5
# formatting number column type with header:BP SYSTOLIC CURRENT
# formatting number column type with header:BP SYSTOLIC PERIOD 1
# formatting number column type with header:BP SYSTOLIC PERIOD 2
# formatting number column type with header:BP SYSTOLIC PERIOD 3
# formatting number column type with header:BP SYSTOLIC PERIOD 4
# formatting number column type with header:BP SYSTOLIC PERIOD 5
# formatting number column type with header:LDL CURRENT
# formatting number column type with header:LDL PERIOD 1
# formatting number column type with header:LDL PERIOD 2
# formatting number column type with header:LDL PERIOD 3
# formatting number column type with header:LDL PERIOD 4
# formatting number column type with header:LDL PERIOD 5
# formatting number column type with header:HDL CURRENT
# formatting number column type with header:HDL PERIOD 1
# formatting number column type with header:HDL PERIOD 2
# formatting number column type with header:HDL PERIOD 3
# formatting number column type with header:HDL PERIOD 4
# formatting number column type with header:HDL PERIOD 5
# formatting number column type with header:BRFSS INDEX
# formatting number column type with header: STATE
# formatting number column type with header:FMONTH
# formatting number column type with header:IDATE
# formatting number column type with header:IMONTH
# formatting number column type with header:IDAY
# formatting number column type with header:IYEAR
# formatting number column type with header:DISPCODE
# formatting number column type with header:SEQNO
# formatting number column type with header: PSU
# formatting number column type with header:CTELENUM
# formatting number column type with header:PVTRESD1
# formatting number column type with header:COLGHOUS
# formatting number column type with header:STATERES
# formatting number column type with header:CELLFON3
# formatting number column type with header:LADULT
# formatting number column type with header:NUMADULT
# formatting number column type with header:NUMMEN
# formatting number column type with header:NUMWOMEN
# formatting number column type with header:CTELNUM1
# formatting number column type with header:CELLFON2
# formatting number column type with header:CADULT
# formatting number column type with header:PVTRESD2
# formatting number column type with header:CCLGHOUS
# formatting number column type with header:CSTATE
# formatting number column type with header:LANDLINE
# formatting number column type with header:HHADULT
# formatting number column type with header:GENHLTH
# formatting number column type with header:PHYSHLTH
# formatting number column type with header:MENTHLTH
# formatting number column type with header:POORHLTH
# formatting number column type with header:HLTHPLN1
# formatting number column type with header:PERSDOC2
# formatting number column type with header:MEDCOST
# formatting number column type with header:MEDCOST   WAS THERE A TIME DURING THE PAST 12 MONTHS WHEN YOU NEEDED TO SEE A DOCTOR, BUT COULD NOT BECAUSE OF THE COST? ?  1=YES 2=NO 7=DK/NOT SURE 9=REFUSED
# formatting number column type with header:CHECKUP1
# formatting number column type with header:CHECKUP1  ABOUT HOW LONG HAS IT BEEN SINCE YOU LAST VISITED A DOCTOR FOR A ROUTINE CHECKUP?  ?  1=YES 2=NO 7=DK/NOT SURE 9=REFUSED
# formatting number column type with header:BPHIGH4
# formatting number column type with header:BPHIGH4  HAVE YOU EVER BEEN TOLD BY A DOCTOR, NURSE, OR OTHER HEALTH PROFESSIONAL THAT YOU HAVE HIGH BLOOD PRESSURE??  1=YES 2=NO 7=DK/NOT SURE 9=REFUSED
# formatting number column type with header:BPMEDS
# formatting number column type with header:BPMEDS   ARE YOU CURRENTLY TAKING MEDICINE FOR YOUR HIGH BLOOD PRESSURE? ?  1=YES 2=NO 7=DK/NOT SURE 9=REFUSED
# formatting number column type with header:BLOODCHO
# formatting number column type with header:BLOODCHO   BLOOD CHOLESTEROL IS A FATTY SUBSTANCE FOUND IN THE BLOOD.  HAVE YOU EVER HAD YOUR BLOOD CHOLESTEROL CHECKED? ?          1=YES 2=NO 7=DK/NOT SURE 9=REFUSED
# formatting number column type with header:CHOLCHK
# formatting number column type with header:CHOLCHK   WHEN WAS CHOLESTEROL CHECKED?
# formatting number column type with header:TOLDHI2
# formatting number column type with header:TOLDHI2   EVER TOLD  BLOOD CHOLESTEROL IS HIGH? ?  1=YES 2=NO 7=DK/NOT SURE 9=REFUSED
# formatting number column type with header:CVDINFR4
# formatting number column type with header:CVDINFR4   EVER TOLD YOU HAVE HEART ATTACK, ALSO CALLED A MYOCARDIAL INFARCTION ?  1=YES 2=NO 7=DK/NOT SURE 9=REFUSED
# formatting number column type with header:CVDCRHD4
# formatting number column type with header:CVDCRHD4  EVER TOLD YOU HAVE ANGINA OR CORONARY HEART DISEASE ?  1=YES 2=NO 7=DK/NOT SURE 9=REFUSED
# formatting number column type with header:CVDSTRK3
# formatting number column type with header:CVDSTRK3   EVER TOLD YOU HAVE STROKE ?    1=YES 2=NO 7=DK/NOT SURE 9=REFUSED
# formatting number column type with header:ASTHMA3
# formatting number column type with header:ASTHMA3   EVER TOLD YOU HAVE ASTHMA ?  1=YES 2=NO 7=DK/NOT SURE 9=REFUSED
# formatting number column type with header:ASTHNOW
# formatting number column type with header:ASTHNOW DO YOU STILL HAVE ASTHMA?  1=YES 2=NO 7=DK/NOT SURE 9=REFUSED
# formatting number column type with header:CHCSCNCR
# formatting number column type with header:CHCSCNCR (EVER TOLD) YOU HAVE SKIN CANCER?  1=YES 2=NO 7=DK/NOT SURE 9=REFUSED
# formatting number column type with header:CHCOCNCR
# formatting number column type with header:CHCOCNCR (EVER TOLD) YOU HAVE OTHER TYPES OF CANCER?  1=YES 2=NO 7=DK/NOT SURE 9=REFUSED
# formatting number column type with header:CHCCOPD1
# formatting number column type with header:CHCCOPD1 (EVER TOLD) YOU HAVE CHRONIC OBSTRUCTIVE PULMONARY DISEASE OR COPD, EMPHYSEMA OR CHRONIC BRONCHITIS?  1=YES 2=NO 7=DK/NOT SURE 9=REFUSED
# formatting number column type with header:HAVARTH3
# formatting number column type with header:ADDEPEV2 -  EVER BEEN TOLD YOU HAVE ARTHRITIS ?    1=YES 2=NO 7=DK/NOT SURE 9=REFUSED
# formatting number column type with header:ADDEPEV2
# formatting number column type with header:ADDEPEV2 -  EVER BEEN TOLD YOU HAVE DEPPRESION OR DEPRESSIVE DISORDER?    1=YES 2=NO 7=DK/NOT SURE 9=REFUSED
# formatting number column type with header:CHCKIDNY
# formatting number column type with header:CHCKIDNY - EVER BEEN TOLD YOU HAVE KIDNEY DISEASE?  1=YES 2=NO 7=DK / NOT SURE 9=REFUSED
# formatting number column type with header:DIABETE3
# formatting number column type with header:DIABETE3 EVER BEEN TOLD YOU HAVE DIABETES? 1=YES 2=YES, BUT FEMALE TOLD ONLY DURING PREGNANCY 3=NO 4=NO, PRE-DIABETES OR BORDERLINE DIABETES 7=DK/NS 9=REFUSED
# formatting number column type with header:DIABAGE2
# formatting number column type with header:DIABAGE2 AGE TOLD OF DIABETES 1-97=AGE IN YEARS  [97 = 97 AND OLDER] 98=DON’T KNOW/NOT SURE 99=REFUSED
# formatting number column type with header:SEX
# formatting number column type with header:SEX 1=MALE 2=FEMALE 7=DON’T KNOW/NOT SURE 9=REFUSED
# formatting number column type with header:MARITAL
# formatting number column type with header:MARITAL  1=MARRIED  2=DIVORCED  3=WIDOWED  4=SEPARATED  5=NEVER MARRIED  6=A MEMBER OF AN UNMARRIED COUPLE  9=REFUSED
# formatting number column type with header:EDUCA
# formatting number column type with header:EDUCA 1=NEVER ATTENDED SCHOOL OR ONLY ATTENDED KINDERGARTEN  2=GRADES 1 THROUGH 8 (ELEMENTARY)  3=GRADES 9 THROUGH 11 (SOME HIGH SCHOOL)  4=GRADE 12 OR GED (HIGH SCHOOL GRADUATE)  5=COLLEGE 1 YEAR TO 3 YEARS (SOME COLLEGE OR TECHNICAL SCHOOL)  6=COLLEGE 4 YEARS
# formatting number column type with header:RENTHOM1
# formatting number column type with header:DO YOU OWN OR RENT YOUR HOME? 1=OWN  2=RENT  3=OTHER ARRANGEMENT
# formatting number column type with header:NUMHHOL2
# formatting number column type with header:1=YES 2=NO 7=DK / NOT SURE 9=REFUSED
# formatting number column type with header:NUMPHON2
# formatting number column type with header:1=YES 2=NO 7=DK / NOT SURE 9=REFUSED.1
# formatting number column type with header:CPDEMO1
# formatting number column type with header:1=YES 2=NO 7=DK / NOT SURE 9=REFUSED.2
# formatting number column type with header:VETERAN3
# formatting number column type with header:1=YES 2=NO 7=DK / NOT SURE 9=REFUSED.3
# formatting number column type with header:EMPLOY1
# formatting number column type with header:1=YES 2=NO 7=DK / NOT SURE 9=REFUSED.4
# formatting number column type with header:CHILDREN
# formatting number column type with header:1=YES 2=NO 7=DK / NOT SURE 9=REFUSED.5
# formatting number column type with header:INCOME2
# formatting number column type with header:04=LESS THAN $25,000   ($20,000 TO LESS THAN $25,000)   03=LESS THAN $20,000   ($15,000 TO LESS THAN $20,000)   02=LESS THAN $15,000   ($10,000 TO LESS THAN $15,000)   01=LESS THAN $10,000   05=LESS THAN $35,000   ($25,000 TO LESS THAN $35,000)   06=LESS
# formatting number column type with header:INTERNET
# formatting number column type with header:1=YES 2=NO 7=DK / NOT SURE 9=REFUSED.6
# formatting number column type with header:WEIGHT2
# formatting number column type with header:HEIGHT3
# formatting number column type with header:PREGNANT
# formatting number column type with header:QLACTLM2
# formatting number column type with header:USEEQUIP
# formatting number column type with header:BLIND
# formatting number column type with header:DECIDE
# formatting number column type with header:DIFFWALK
# formatting number column type with header:DIFFDRES
# formatting number column type with header:DIFFALON
# formatting number column type with header:SMOKE100
# formatting number column type with header:SMOKDAY2
# formatting number column type with header:STOPSMK2
# formatting number column type with header:LASTSMK2
# formatting number column type with header:USENOW3
# formatting number column type with header:ALCDAY5
# formatting number column type with header:AVEDRNK2
# formatting number column type with header:DRNK3GE5
# formatting number column type with header:MAXDRNKS
# formatting number column type with header:FRUITJU1
# formatting number column type with header:FRUIT1
# formatting number column type with header:FVBEANS
# formatting number column type with header:FVGREEN
# formatting number column type with header:FVORANG
# formatting number column type with header:VEGETAB1
# formatting number column type with header:EXERANY2
# formatting number column type with header:EXRACT11
# formatting number column type with header:EXEROFT1
# formatting number column type with header:EXERHMM1
# formatting number column type with header:EXRACT21
# formatting number column type with header:EXEROFT2
# formatting number column type with header:EXERHMM2
# formatting number column type with header:STRENGTH
# formatting number column type with header:LMTJOIN3
# formatting number column type with header:ARTHDIS2
# formatting number column type with header:ARTHSOCL
# formatting number column type with header:JOINPAIN
# formatting number column type with header:SEATBELT
# formatting number column type with header:FLUSHOT6
# formatting number column type with header:FLSHTMY2
# formatting number column type with header:IMFVPLAC
# formatting number column type with header:PNEUVAC3
# formatting number column type with header:HIVTST6
# formatting number column type with header:HIVTSTD3
# formatting number column type with header:WHRTST10
# formatting number column type with header:PDIABTST
# formatting number column type with header:PREDIAB1
# formatting number column type with header:INSULIN
# formatting number column type with header:BLDSUGAR
# formatting number column type with header:FEETCHK2
# formatting number column type with header:DOCTDIAB
# formatting number column type with header:CHKHEMO3
# formatting number column type with header:FEETCHK
# formatting number column type with header:EYEEXAM
# formatting number column type with header:DIABEYE
# formatting number column type with header:DIABEDU
# formatting number column type with header:PAINACT2
# formatting number column type with header:QLMENTL2
# formatting number column type with header:QLSTRES2
# formatting number column type with header:QLHLTH2
# formatting number column type with header:CAREGIV1
# formatting number column type with header:CRGVREL1
# formatting number column type with header:CRGVLNG1
# formatting number column type with header:CRGVHRS1
# formatting number column type with header:CRGVPRB1
# formatting number column type with header:CRGVPERS
# formatting number column type with header:CRGVHOUS
# formatting number column type with header:CRGVMST2
# formatting number column type with header:CRGVEXPT
# formatting number column type with header:VIDFCLT2
# formatting number column type with header:VIREDIF3
# formatting number column type with header:VIPRFVS2
# formatting number column type with header:VINOCRE2
# formatting number column type with header:VIEYEXM2
# formatting number column type with header:VIINSUR2
# formatting number column type with header:VICTRCT4
# formatting number column type with header:VIGLUMA2
# formatting number column type with header:VIMACDG2
# formatting number column type with header:CIMEMLOS
# formatting number column type with header:CDHOUSE
# formatting number column type with header:CDASSIST
# formatting number column type with header:CDHELP
# formatting number column type with header:CDSOCIAL
# formatting number column type with header:CDDISCUS
# formatting number column type with header:WTCHSALT
# formatting number column type with header:LONGWTCH
# formatting number column type with header:DRADVISE
# formatting number column type with header:ASTHMAGE
# formatting number column type with header:ASATTACK
# formatting number column type with header:ASERVIST
# formatting number column type with header:ASDRVIST
# formatting number column type with header:ASRCHKUP
# formatting number column type with header:ASACTLIM
# formatting number column type with header:ASYMPTOM
# formatting number column type with header:ASNOSLEP
# formatting number column type with header:ASTHMED3
# formatting number column type with header:ASINHALR
# formatting number column type with header:HAREHAB1
# formatting number column type with header:STREHAB1
# formatting number column type with header:CVDASPRN
# formatting number column type with header:ASPUNSAF
# formatting number column type with header:RLIVPAIN
# formatting number column type with header:RDUCHART
# formatting number column type with header:RDUCSTRK
# formatting number column type with header:ARTTODAY
# formatting number column type with header:ARTHWGT
# formatting number column type with header:ARTHEXER
# formatting number column type with header:ARTHEDU
# formatting number column type with header:TETANUS
# formatting number column type with header:HPVADVC2
# formatting number column type with header:HPVADSHT
# formatting number column type with header:SHINGLE2
# formatting number column type with header:HADMAM
# formatting number column type with header:HOWLONG
# formatting number column type with header:HADPAP2
# formatting number column type with header:LASTPAP2
# formatting number column type with header:HPVTEST
# formatting number column type with header:HPLSTTST
# formatting number column type with header:HADHYST2
# formatting number column type with header:PROFEXAM
# formatting number column type with header:LENGEXAM
# formatting number column type with header:BLDSTOOL
# formatting number column type with header:LSTBLDS3
# formatting number column type with header:HADSIGM3
# formatting number column type with header:HADSGCO1
# formatting number column type with header:LASTSIG3
# formatting number column type with header:PCPSAAD2
# formatting number column type with header:PCPSADI1
# formatting number column type with header:PCPSARE1
# formatting number column type with header:PSATEST1
# formatting number column type with header:PSATIME
# formatting number column type with header:PCPSARS1
# formatting number column type with header:PCPSADE1
# formatting number column type with header:PCDMDECN
# formatting number column type with header:SCNTMNY1
# formatting number column type with header:SCNTMEL1
# formatting number column type with header:SCNTPAID
# formatting number column type with header:SCNTWRK1
# formatting number column type with header:SCNTLPAD
# formatting number column type with header:SCNTLWK1
# formatting number column type with header:SXORIENT
# formatting number column type with header:TRNSGNDR
# formatting number column type with header:RCSGENDR
# formatting number column type with header:RCSRLTN2
# formatting number column type with header:CASTHDX2
# formatting number column type with header:CASTHNO2
# formatting number column type with header:EMTSUPRT
# formatting number column type with header:LSATISFY
# formatting number column type with header:ADPLEASR
# formatting number column type with header:ADDOWN
# formatting number column type with header:ADSLEEP
# formatting number column type with header:ADENERGY
# formatting number column type with header:ADEAT1
# formatting number column type with header:ADFAIL
# formatting number column type with header:ADTHINK
# formatting number column type with header:ADMOVE
# formatting number column type with header:MISTMNT
# formatting number column type with header:ADANXEV
# formatting number column type with header:QSTVER
# formatting number column type with header:QSTLANG
# formatting number column type with header:EXACTOT1
# formatting number column type with header:EXACTOT2
# formatting number column type with header:MSCODE
# formatting number column type with header: STSTR
# formatting number column type with header: STRWT
# formatting number column type with header: RAWRAKE
# formatting number column type with header: WT2RAKE
# formatting number column type with header: CHISPNC
# formatting number column type with header: CRACE1
# formatting number column type with header: CPRACE
# formatting number column type with header: CLLCPWT
# formatting number column type with header: DUALUSE
# formatting number column type with header: DUALCOR
# formatting number column type with header: LLCPWT
# formatting number column type with header: RFHLTH
# formatting number column type with header: HCVU651
# formatting number column type with header: RFHYPE5
# formatting number column type with header: CHOLCHK
# formatting number column type with header: RFCHOL
# formatting number column type with header: MICHD
# formatting number column type with header: LTASTH1
# formatting number column type with header: CASTHM1
# formatting number column type with header: ASTHMS1
# formatting number column type with header: DRDXAR1
# formatting number column type with header: PRACE1
# formatting number column type with header: MRACE1
# formatting number column type with header: HISPANC
# formatting number column type with header: RACE
# ...
# formatting number column type with header:ORNGDAY
# formatting number column type with header:VEGEDA1
# formatting number column type with header: MISFRTN
# formatting number column type with header: MISVEGN
# formatting number column type with header: FRTRESP
# formatting number column type with header:UNNAMED: 422
# formatting number column type with header: VEGRESP
# formatting number column type with header:UNNAMED: 424
# formatting number column type with header: FRUTSUM
# formatting number column type with header:UNNAMED: 426
# formatting number column type with header: VEGESUM
# formatting number column type with header:X VEGESUM: TOTAL VEGETABLES CONSUMED PER DAY
# formatting number column type with header: FRTLT1
# formatting number column type with header: VEGLT1
# formatting number column type with header: FRT16
# formatting number column type with header: VEG23
# formatting number column type with header: FRUITEX
# formatting number column type with header:X FRUITEX: FRUIT EXCLUSION FROM ANALYSES
# formatting number column type with header: VEGETEX
# formatting number column type with header:X VEGETEX: VEGETABLE EXCLUSION FROM ANALYSES
# formatting number column type with header: TOTINDA
# formatting number column type with header:METVL11
# formatting number column type with header:METVL21
# formatting number column type with header:MAXVO2
# formatting number column type with header:FC60
# formatting number column type with header:ACTIN11
# formatting number column type with header:ACTIN21
# formatting number column type with header:PADUR1
# formatting number column type with header:PADUR2
# formatting number column type with header:PAFREQ1
# formatting number column type with header:PAFREQ2
# formatting number column type with header:PAFREQ2 : PHYSICAL ACTIVITY FREQUENCY PER WEEK FOR SECOND ACTIVITY
# formatting number column type with header: MINAC11
# formatting number column type with header: MINAC21
# formatting number column type with header:STRFREQ
# formatting number column type with header:PAMISS1
# formatting number column type with header:PAMIN11
# formatting number column type with header:PAMIN11 : MINUTES OF PHYSICAL ACTIVITY PER WEEK FOR FIRST ACTIVITY
# formatting number column type with header:PAMIN21
# formatting number column type with header:PAMIN21 : MINUTES OF PHYSICAL ACTIVITY PER WEEK FOR SECOND ACTIVITY
# formatting number column type with header:PA1MIN
# formatting number column type with header:PA1MIN : MINUTES OF TOTAL PHYSICAL ACTIVITY PER WEEK
# formatting number column type with header:PAVIG11
# formatting number column type with header:PAVIG21
# formatting number column type with header:PA1VIGM
# formatting number column type with header: PACAT1
# formatting number column type with header: PAINDX1
# formatting number column type with header: PA150R2
# formatting number column type with header: PA300R2
# formatting number column type with header: PA30021
# formatting number column type with header: PASTRNG
# formatting number column type with header: PAREC1
# formatting number column type with header: PASTAE1
# formatting number column type with header: LMTACT1
# formatting number column type with header: LMTWRK1
# formatting number column type with header: LMTSCL1
# formatting number column type with header: RFSEAT2
# formatting number column type with header: RFSEAT3
# formatting number column type with header: FLSHOT6
# formatting number column type with header: PNEUMO2
# formatting number column type with header: AIDTST3
# formatting number column type with header:PAM Q1
# formatting number column type with header:PAM Q2
# formatting number column type with header:PAM Q3
# formatting number column type with header:PAM Q4
# formatting number column type with header:PAM Q5
# formatting number column type with header:PAM Q6
# formatting number column type with header:PAM Q7
# formatting number column type with header:PAM Q8
# formatting number column type with header:PAM Q9
# formatting number column type with header:PAM Q10
# formatting number column type with header:PAM Q11
# formatting number column type with header:PAM Q12
# formatting number column type with header:PAM Q13
# Formatting file:C:\working_directory\excel\AIHS_patient.xlsx with maximum Coluns:493 template:standard
#
# Read in raw file:C:\working_directory\excel\AIHS_patient.xlsx
# Worksheet Sheet1
# Formatted:C:\working_directory\excel\AIHS_patient_ft.xlsx
# File name to be loaded:C:\working_directory\excel\Annual_Wellness_Visits_Patient_Detail_12_8_2022.xlsx
#
#
# Formatting file:C:\working_directory\excel\Annual_Wellness_Visits_Patient_Detail_12_8_2022.xlsx with maximum Columns:28 template:standard
# after add logo
# format_column_header max_row:112310 max_col:27
# format_column_header value:ORGANIZATION_CLASS
# format_column_header value:ORGANIZATION_NAME
# format_column_header value:PROVIDER_NAME
# format_column_header value:PATIENT_NAME
# format_column_header value:LAST_AWV_DATE
# format_column_header value:AWV_PROCEDURE_CODE
# format_column_header value:AWV_SOURCE_DESCRIPTION
# format_column_header value:DAYS_SINCE_AWV
# format_column_header value:AWV_365_DAY_STATUS
# format_column_header value:AWV_CALENDAR_YEAR_STATUS
# format_column_header value:AGE_CATEGORIES
# format_column_header value:BIRTH_DATE
# format_column_header value:AGE_YEARS
# format_column_header value:AGE
# format_column_header value:GENDER
# format_column_header value:PLAN_NAME
# format_column_header value:PAYER_NAME
# format_column_header value:EMAIL_ADDRESS
# format_column_header value:PHONE
# format_column_header value:DECEASED
# format_column_header value:DECEASED_DATE
# format_column_header value:NUMBER_OF_CONDITIONS
# format_column_header value:CLAIM_COUNT
# format_column_header value:ENCOUNTER_COUNT
# format_column_header value:MOST_RECENT_DATE_OF_SERVICE
# format_column_header value:MARA_RISK_SCORE
# format_column_header value:NUMBER_OF_HCC
# formatting number column type with header:ORGANIZATION CLASS
# formatting number column type with header:ORGANIZATION NAME
# formatting number column type with header:PROVIDER NAME
# formatting number column type with header:PATIENT NAME
# formatting number column type with header:LAST AWV DATE
# formatting number column type with header:AWV PROCEDURE CODE
# formatting number column type with header:AWV SOURCE DESCRIPTION
# formatting number column type with header:DAYS SINCE AWV
# formatting number column type with header:AWV 365 DAY STATUS
# formatting number column type with header:AWV CALENDAR YEAR STATUS
# formatting number column type with header:AGE CATEGORIES
# formatting number column type with header:BIRTH DATE
# formatting number column type with header:AGE YEARS
# formatting number column type with header:AGE
# formatting number column type with header:GENDER
# formatting number column type with header:PLAN NAME
# formatting number column type with header:PAYER NAME
# formatting number column type with header:EMAIL ADDRESS
# formatting number column type with header:PHONE
# formatting number column type with header:DECEASED
# formatting number column type with header:DECEASED DATE
# formatting number column type with header:NUMBER OF CONDITIONS
# formatting number column type with header:CLAIM COUNT
# formatting number column type with header:ENCOUNTER COUNT
# formatting number column type with header:MOST RECENT DATE OF SERVICE
# formatting number column type with header:MARA RISK SCORE
# formatting number column type with header:NUMBER OF HCC
# Formatting file:C:\working_directory\excel\Annual_Wellness_Visits_Patient_Detail_12_8_2022.xlsx with maximum Coluns:28 template:standard
#
# Read in raw file:C:\working_directory\excel\Annual_Wellness_Visits_Patient_Detail_12_8_2022.xlsx
# Worksheet query-results-December 8th 2022
# Formatted:C:\working_directory\excel\Annual_Wellness_Visits_Patient_Detail_12_8_2022_ft.xlsx
# File name to be loaded:C:\working_directory\excel\Annual_Wellness_Visits_Patient_Detail_12_8_2022_less.xlsx
# Formatting file:C:\working_directory\excel\Annual_Wellness_Visits_Patient_Detail_12_8_2022_less.xlsx with maximum Columns:28 template:standard
# after add logo
# format_column_header max_row:65892 max_col:27
# format_column_header value:ORGANIZATION_CLASS
# format_column_header value:ORGANIZATION_NAME
# format_column_header value:PROVIDER_NAME
# format_column_header value:PATIENT_NAME
# format_column_header value:LAST_AWV_DATE
# format_column_header value:AWV_PROCEDURE_CODE
# format_column_header value:AWV_SOURCE_DESCRIPTION
# format_column_header value:DAYS_SINCE_AWV
# format_column_header value:AWV_365_DAY_STATUS
# format_column_header value:AWV_CALENDAR_YEAR_STATUS
# format_column_header value:AGE_CATEGORIES
# format_column_header value:BIRTH_DATE
# format_column_header value:AGE_YEARS
# format_column_header value:AGE
# format_column_header value:GENDER
# format_column_header value:PLAN_NAME
# format_column_header value:PAYER_NAME
# format_column_header value:EMAIL_ADDRESS
# format_column_header value:PHONE
# format_column_header value:DECEASED
# format_column_header value:DECEASED_DATE
# format_column_header value:NUMBER_OF_CONDITIONS
# format_column_header value:CLAIM_COUNT
# format_column_header value:ENCOUNTER_COUNT
# format_column_header value:MOST_RECENT_DATE_OF_SERVICE
# format_column_header value:MARA_RISK_SCORE
# format_column_header value:NUMBER_OF_HCC
# formatting number column type with header:ORGANIZATION CLASS
# formatting number column type with header:ORGANIZATION NAME
# formatting number column type with header:PROVIDER NAME
# formatting number column type with header:PATIENT NAME
# formatting number column type with header:LAST AWV DATE
# formatting number column type with header:AWV PROCEDURE CODE
# formatting number column type with header:AWV SOURCE DESCRIPTION
# formatting number column type with header:DAYS SINCE AWV
# formatting number column type with header:AWV 365 DAY STATUS
# formatting number column type with header:AWV CALENDAR YEAR STATUS
# formatting number column type with header:AGE CATEGORIES
# formatting number column type with header:BIRTH DATE
# formatting number column type with header:AGE YEARS
# formatting number column type with header:AGE
# formatting number column type with header:GENDER
# formatting number column type with header:PLAN NAME
# formatting number column type with header:PAYER NAME
# formatting number column type with header:EMAIL ADDRESS
# formatting number column type with header:PHONE
# formatting number column type with header:DECEASED
# formatting number column type with header:DECEASED DATE
# formatting number column type with header:NUMBER OF CONDITIONS
# formatting number column type with header:CLAIM COUNT
# formatting number column type with header:ENCOUNTER COUNT
# formatting number column type with header:MOST RECENT DATE OF SERVICE
# formatting number column type with header:MARA RISK SCORE
# formatting number column type with header:NUMBER OF HCC
# Formatting file:C:\working_directory\excel\Annual_Wellness_Visits_Patient_Detail_12_8_2022_less.xlsx with maximum Coluns:28 template:standard
#
# Read in raw file:C:\working_directory\excel\Annual_Wellness_Visits_Patient_Detail_12_8_2022_less.xlsx
# Worksheet Sheet1
# Formatted:C:\working_directory\excel\Annual_Wellness_Visits_Patient_Detail_12_8_2022_less_ft.xlsx
# File name to be loaded:C:\working_directory\excel\design_goal.xlsx
#
#
# Formatting file:C:\working_directory\excel\design_goal.xlsx with maximum Columns:3 template:standard
# after add logo
# format_column_header max_row:16 max_col:2
# format_column_header value:design_goal
# format_column_header value:design_goal_description
# formatting number column type with header:DESIGN GOAL
# formatting number column type with header:DESIGN GOAL DESCRIPTION
# Formatting file:C:\working_directory\excel\design_goal.xlsx with maximum Coluns:3 template:standard
#
# Read in raw file:C:\working_directory\excel\design_goal.xlsx
# Worksheet Sheet1
# Formatted:C:\working_directory\excel\design_goal_ft.xlsx
# File name to be loaded:C:\working_directory\excel\design_goals.xlsx
#
#
# Formatting file:C:\working_directory\excel\design_goals.xlsx with maximum Columns:3 template:standard
# after add logo
# format_column_header max_row:16 max_col:2
# format_column_header value:design_goal
# format_column_header value:design_goal_description
# formatting number column type with header:DESIGN GOAL
# formatting number column type with header:DESIGN GOAL DESCRIPTION
# Formatting file:C:\working_directory\excel\design_goals.xlsx with maximum Coluns:3 template:standard
#
# Read in raw file:C:\working_directory\excel\design_goals.xlsx
# Worksheet Sheet1
# Formatted:C:\working_directory\excel\design_goals_ft.xlsx
# File name to be loaded:C:\working_directory\excel\Discovered_CSV_files_to_import.xlsx
#
#
# Formatting file:C:\working_directory\excel\Discovered_CSV_files_to_import.xlsx with maximum Columns:8 template:standard
# after add logo
# format_column_header max_row:35 max_col:7
# format_column_header value:Root_Directory
# format_column_header value:Sub_Directory
# format_column_header value:Table_Name
# format_column_header value:Import_File_Name
# format_column_header value:File_Size
# format_column_header value:File_Modified_Date
# format_column_header value:File_Created_Date
# formatting number column type with header:ROOT DIRECTORY
# formatting number column type with header:SUB DIRECTORY
# formatting number column type with header:TABLE NAME
# formatting number column type with header:IMPORT FILE NAME
# formatting number column type with header:FILE SIZE
# formatting number column type with header:FILE MODIFIED DATE
# formatting number column type with header:FILE CREATED DATE
# Formatting file:C:\working_directory\excel\Discovered_CSV_files_to_import.xlsx with maximum Coluns:8 template:standard
#
# Read in raw file:C:\working_directory\excel\Discovered_CSV_files_to_import.xlsx
# Worksheet Sheet1
# Formatted:C:\working_directory\excel\Discovered_CSV_files_to_import_ft.xlsx
# File name to be loaded:C:\working_directory\excel\Discovered_CSV_files_to_import_PB_JAE.xlsx
#
#
# Formatting file:C:\working_directory\excel\Discovered_CSV_files_to_import_PB_JAE.xlsx with maximum Columns:5 template:standard
# after add logo
# format_column_header max_row:1939 max_col:4
# format_column_header value:Discovery Import Files
# format_column_header value:None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 testing = True
#       2 if testing:
# ----> 3     formatted_excel_Files = re.format_excel_directory('C:\working_directory\excel')
#       4     print(f'/n/nFormatted #{formatted_excel_Files} excel files')
#
# File ~\rpa_excel.py:357, in format_excel_directory(directory, template)
#     355 if (file.find('_ft') == -1) & (file.find('_pb') == -1) & (file.find('~$') == -1): # already formatted
#     356     print(f'File name to be loaded:{file}')
# --> 357     status = format_workbook(file, template)
#     358     formatted_files += 1
#     359     logging.info(f'{status}')
#
# File ~\rpa_excel.py:339, in format_workbook(filename, template)
#     336     format_filename = filename.replace('.xlsx','_ft.xlsx')
#     338     for sheet in wb:
# --> 339         status =  status + '\n'+ format_worksheet(sheet, filename, template)
#     341 # Save the file to persist the changes
#     342     add_meta_tab(wb, 'report_header', filename)
#
# File ~\rpa_excel.py:281, in format_worksheet(ws, filename, template)
#     278     full_data_range = "A2:" + get_column_letter(ws.max_column) + str(ws.max_row)
#     279     ws.auto_filter.ref = full_data_range
# --> 281 format_column_header(ws)     # Format the Header as text bold and backgound light blue centered wordwrap
#     284 default_column_width = 15
#     285 if template == 'quality_report':
#
# File ~\rpa_excel.py:93, in format_column_header(ws)
#      91             ws[get_column_letter(col) + '2'].fill = PatternFill("solid", start_color=HEADER_COLOR)
#      92             ws[get_column_letter(col) + '2'].alignment = Alignment(horizontal='center', wrap_text=True)
# ---> 93             ws[get_column_letter(col) + '2'].value = str(ws[get_column_letter(col) + '2'].value).title().replace('_',' ')
#      94 return ws.max_column
#
# AttributeError: 'MergedCell' object attribute 'value' is read-only

# %%
testing = False
if testing:
    formatted_excel_Files = re.format_excel_file('Z:\\PRE-PRODUCTION documentation\\FM\\RITM0043591\\ACO Demographic.xlsx')
    print(f'/n/nFormatted #{formatted_excel_Files} excel files') 
    
#     Z:\\PRE-PRODUCTION documentation\\FM\\RITM0043591\\ACO Demographic.xlsx
# here Y:\PRE-PRODUCTION documentation\FM\RITM0043591 its called “ACO Demographic”

# %%
testing = False 
if testing:
    formatted_excel_Files = re.format_excel_directory('C:\working_directory\excel\gaps_in_care')
    print(f'Formatted #{formatted_excel_Files} excel files')

# %%
# Calculate and classify the process performance 
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))
